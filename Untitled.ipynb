# %%
import pandas as pd

# %%
file1 = "crime12.xlsx"
pd.read_excel(file1)
# Out:
#        Unnamed: 0       Unnamed: 1  Unnamed: 2       Unnamed: 3  \
# 0             NaN              NaN         NaN              NaN
# 1             NaN              NaN         NaN              NaN
# 2             NaN              NaN         NaN              NaN
# 3             NaN              NaN         NaN              NaN
# 4             NaN              NaN         NaN              NaN
# 5             NaN              NaN         NaN              NaN
# 6             NaN              NaN         NaN              NaN
# 7             NaN              NaN         NaN              NaN
# 8             NaN              NaN         NaN              NaN
# 9             NaN             None         NaN             None
# 10            NaN  Occurrence Date         NaN  Occurrence Hour
# 11            NaN       2018-12-01         NaN               00
# 12            NaN       2018-12-01         NaN               00
# 13            NaN       2018-12-01         NaN               00
# ...

# %%
file1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-9203f9db80d3> in <module>
# ----> 1 file1.head()
#
# AttributeError: 'str' object has no attribute 'head'
