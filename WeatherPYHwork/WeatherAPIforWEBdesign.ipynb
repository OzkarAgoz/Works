# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
temp_units ='imperial'

# query url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_information_by_city = {}
for index, city in enumerate(cities):
    try:
        response = requests.get(query_url + city.replace(" ", "&")).json()
        cloudiness = response['clouds']['all']
        country = response['sys']['country']
        dt = response['dt']
        humidity = response['main']['humidity']
        max_temperature = response['main']['temp_max']
        lat = response['coord']['lat']
        lon = response['coord']['lon']
        wind_speed = response['wind']['speed']
        weather_information_by_city[city] = {
            'cloudiness': cloudiness,
            'country': country,
            'dt': dt,
            'humidity': humidity,
            'max_temperature': max_temperature,
            'lat': lat,
            'lon': lon,
            'wind_speed': wind_speed
        }
        print('Currently processing city %s with index %s', city, index)
    except requests.exceptions.HTTPError as err:
        print('HTTP Connection error occurred for city %s. Skipping...', city)
        print(err)
    except KeyError as err:
        print('Key error occurred for city %s. Skipping...', city)
        print(err)
# Out:
# Key error occurred for city %s. Skipping... barbar
# 'clouds'
# Currently processing city %s with index %s grand river south east 1
# Currently processing city %s with index %s kovur 2
# Currently processing city %s with index %s bredasdorp 3
# Currently processing city %s with index %s saldanha 4
# Currently processing city %s with index %s bluff 5
# Currently processing city %s with index %s shimoda 6
# Currently processing city %s with index %s komsomolskiy 7
# Currently processing city %s with index %s saint-augustin 8
# Currently processing city %s with index %s brae 9
# Currently processing city %s with index %s rikitea 10
# Currently processing city %s with index %s klaksvik 11
# Currently processing city %s with index %s muzhi 12
# Currently processing city %s with index %s hermanus 13
# Currently processing city %s with index %s ushuaia 14
# Currently processing city %s with index %s guerrero negro 15
# Currently processing city %s with index %s nikolskoye 16
# Currently processing city %s with index %s surt 17
# Currently processing city %s with index %s busselton 18
# Currently processing city %s with index %s camacha 19
# Currently processing city %s with index %s punta arenas 20
# Currently processing city %s with index %s micheweni 21
# Currently processing city %s with index %s north branch 22
# Currently processing city %s with index %s upernavik 23
# Currently processing city %s with index %s mahebourg 24
# Currently processing city %s with index %s mataura 25
# Currently processing city %s with index %s vaini 26
# Currently processing city %s with index %s jamestown 27
# Currently processing city %s with index %s longonjo 28
# Currently processing city %s with index %s esperance 29
# Currently processing city %s with index %s san angelo 30
# Currently processing city %s with index %s nova olimpia 31
# Currently processing city %s with index %s olutanga 32
# Currently processing city %s with index %s byron bay 33
# Key error occurred for city %s. Skipping... do gonbadan
# 'clouds'
# Currently processing city %s with index %s avarua 35
# Currently processing city %s with index %s nelson bay 36
# Currently processing city %s with index %s chokurdakh 37
# Currently processing city %s with index %s puerto ayora 38
# Currently processing city %s with index %s bambous virieux 39
# Currently processing city %s with index %s kaitangata 40
# Currently processing city %s with index %s bocaiuva 41
# Currently processing city %s with index %s thompson 42
# Currently processing city %s with index %s tsimlyansk 43
# Currently processing city %s with index %s gorontalo 44
# Currently processing city %s with index %s yellowknife 45
# Currently processing city %s with index %s pestretsy 46
# Currently processing city %s with index %s panzhihua 47
# Currently processing city %s with index %s vestnes 48
# Currently processing city %s with index %s lavrentiya 49
# Currently processing city %s with index %s mastung 50
# Currently processing city %s with index %s hobart 51
# Currently processing city %s with index %s tuktoyaktuk 52
# Currently processing city %s with index %s emba 53
# Currently processing city %s with index %s deputatskiy 54
# Currently processing city %s with index %s east london 55
# Currently processing city %s with index %s ahipara 56
# Currently processing city %s with index %s new norfolk 57
# Currently processing city %s with index %s zhezkazgan 58
# Currently processing city %s with index %s butaritari 59
# Currently processing city %s with index %s allapalli 60
# Currently processing city %s with index %s linjiang 61
# Currently processing city %s with index %s teguldet 62
# Currently processing city %s with index %s severobaykalsk 63
# Currently processing city %s with index %s airai 64
# Currently processing city %s with index %s belokurikha 65
# Currently processing city %s with index %s norman wells 66
# Currently processing city %s with index %s hilo 67
# Currently processing city %s with index %s syava 68
# Currently processing city %s with index %s port augusta 69
# Currently processing city %s with index %s lagoa 70
# Currently processing city %s with index %s port alfred 71
# Currently processing city %s with index %s saint-philippe 72
# Currently processing city %s with index %s cape town 73
# Key error occurred for city %s. Skipping... saleaula
# 'clouds'
# Currently processing city %s with index %s mehran 75
# Currently processing city %s with index %s hamilton 76
# Currently processing city %s with index %s arraial do cabo 77
# Currently processing city %s with index %s maldonado 78
# Key error occurred for city %s. Skipping... bengkulu
# 'clouds'
# Currently processing city %s with index %s joigny 80
# Currently processing city %s with index %s zhuhai 81
# Currently processing city %s with index %s ancud 82
# Currently processing city %s with index %s mar del plata 83
# Currently processing city %s with index %s qaqortoq 84
# Key error occurred for city %s. Skipping... vaitupu
# 'clouds'
# Currently processing city %s with index %s khorinsk 86
# Currently processing city %s with index %s kodiak 87
# Currently processing city %s with index %s yeppoon 88
# Currently processing city %s with index %s albany 89
# Key error occurred for city %s. Skipping... taolanaro
# 'clouds'
# Currently processing city %s with index %s kaifeng 91
# Currently processing city %s with index %s privas 92
# Currently processing city %s with index %s castro 93
# Currently processing city %s with index %s bathsheba 94
# Currently processing city %s with index %s doraha 95
# Currently processing city %s with index %s kapaa 96
# Currently processing city %s with index %s progreso 97
# Currently processing city %s with index %s pontianak 98
# Currently processing city %s with index %s ixtapa 99
# Currently processing city %s with index %s bilma 100
# Currently processing city %s with index %s hasaki 101
# Currently processing city %s with index %s saskylakh 102
# Currently processing city %s with index %s sosva 103
# Currently processing city %s with index %s nome 104
# Key error occurred for city %s. Skipping... pak phanang
# 'clouds'
# Currently processing city %s with index %s bubaque 106
# Currently processing city %s with index %s khatanga 107
# Currently processing city %s with index %s sola 108
# Currently processing city %s with index %s oranjemund 109
# Currently processing city %s with index %s dinghai 110
# Currently processing city %s with index %s jiaocheng 111
# Currently processing city %s with index %s faanui 112
# Currently processing city %s with index %s cayenne 113
# Currently processing city %s with index %s lixourion 114
# Currently processing city %s with index %s vestmannaeyjar 115
# Currently processing city %s with index %s pevek 116
# Currently processing city %s with index %s dikson 117
# Currently processing city %s with index %s mongo 118
# Currently processing city %s with index %s husavik 119
# Currently processing city %s with index %s hailar 120
# Currently processing city %s with index %s puerto baquerizo moreno 121
# Key error occurred for city %s. Skipping... quatre cocos
# 'clouds'
# Currently processing city %s with index %s nanortalik 123
# Key error occurred for city %s. Skipping... linchuan
# 'clouds'
# Currently processing city %s with index %s marienberg 125
# Currently processing city %s with index %s vao 126
# Currently processing city %s with index %s clyde river 127
# Key error occurred for city %s. Skipping... atka
# 'clouds'
# Currently processing city %s with index %s eyl 129
# Currently processing city %s with index %s serenje 130
# Currently processing city %s with index %s georgetown 131
# Currently processing city %s with index %s rawson 132
# Key error occurred for city %s. Skipping... belushya guba
# 'clouds'
# Currently processing city %s with index %s cobh 134
# Currently processing city %s with index %s chuy 135
# Currently processing city %s with index %s buin 136
# Currently processing city %s with index %s jos 137
# Currently processing city %s with index %s carnarvon 138
# Currently processing city %s with index %s meadow lake 139
# Key error occurred for city %s. Skipping... attawapiskat
# 'clouds'
# Key error occurred for city %s. Skipping... marcona
# 'clouds'
# Currently processing city %s with index %s yulara 142
# Currently processing city %s with index %s sorland 143
# Key error occurred for city %s. Skipping... illoqqortoormiut
# 'clouds'
# Currently processing city %s with index %s laguna 145
# Currently processing city %s with index %s minas 146
# Currently processing city %s with index %s west wendover 147
# Currently processing city %s with index %s kaseda 148
# Currently processing city %s with index %s yagodnoye 149
# Currently processing city %s with index %s honiara 150
# Currently processing city %s with index %s kaili 151
# Currently processing city %s with index %s coquimbo 152
# Currently processing city %s with index %s nizwa 153
# Currently processing city %s with index %s rio gallegos 154
# Currently processing city %s with index %s rio tuba 155
# Currently processing city %s with index %s ribeira grande 156
# Currently processing city %s with index %s batagay 157
# Currently processing city %s with index %s ilulissat 158
# Currently processing city %s with index %s piacabucu 159
# Currently processing city %s with index %s maceio 160
# Currently processing city %s with index %s goderich 161
# Key error occurred for city %s. Skipping... te anau
# 'clouds'
# Currently processing city %s with index %s labuhan 163
# Currently processing city %s with index %s nampula 164
# Currently processing city %s with index %s cabo san lucas 165
# Currently processing city %s with index %s amapa 166
# Currently processing city %s with index %s longyearbyen 167
# Currently processing city %s with index %s grindavik 168
# Currently processing city %s with index %s barrow 169
# Key error occurred for city %s. Skipping... los llanos de aridane
# 'clouds'
# Currently processing city %s with index %s marystown 171
# Currently processing city %s with index %s sayyan 172
# Currently processing city %s with index %s aklavik 173
# Currently processing city %s with index %s alghero 174
# Currently processing city %s with index %s dunedin 175
# Currently processing city %s with index %s priargunsk 176
# Currently processing city %s with index %s taltal 177
# Currently processing city %s with index %s zlocieniec 178
# Currently processing city %s with index %s fairbanks 179
# Currently processing city %s with index %s prince albert 180
# Currently processing city %s with index %s kununurra 181
# Currently processing city %s with index %s cherskiy 182
# Currently processing city %s with index %s salta 183
# Key error occurred for city %s. Skipping... palabuhanratu
# 'clouds'
# Currently processing city %s with index %s vardo 185
# Currently processing city %s with index %s hay river 186
# Currently processing city %s with index %s neiafu 187
# Currently processing city %s with index %s kralendijk 188
# Currently processing city %s with index %s severo-kurilsk 189
# Currently processing city %s with index %s elko 190
# Currently processing city %s with index %s narsaq 191
# Currently processing city %s with index %s honningsvag 192
# Currently processing city %s with index %s polyarnyy 193
# Currently processing city %s with index %s broome 194
# Currently processing city %s with index %s rocha 195
# Currently processing city %s with index %s lebu 196
# Currently processing city %s with index %s tasiilaq 197
# Key error occurred for city %s. Skipping... sentyabrskiy
# 'clouds'
# Key error occurred for city %s. Skipping... henties bay
# 'clouds'
# Currently processing city %s with index %s vila franca do campo 200
# Currently processing city %s with index %s jardim 201
# Currently processing city %s with index %s mbekenyera 202
# Currently processing city %s with index %s atuona 203
# Currently processing city %s with index %s gornopravdinsk 204
# Currently processing city %s with index %s loreto 205
# Currently processing city %s with index %s verkhnyaya maksakovka 206
# Key error occurred for city %s. Skipping... zlatarica
# 'clouds'
# Key error occurred for city %s. Skipping... walvis bay
# 'clouds'
# Currently processing city %s with index %s okhotsk 209
# Currently processing city %s with index %s bratslav 210
# Currently processing city %s with index %s touros 211
# Currently processing city %s with index %s hambantota 212
# Currently processing city %s with index %s namatanai 213
# Currently processing city %s with index %s sorong 214
# Key error occurred for city %s. Skipping... barentsburg
# 'clouds'
# Currently processing city %s with index %s ponta delgada 216
# Currently processing city %s with index %s bowen 217
# Currently processing city %s with index %s arman 218
# Currently processing city %s with index %s teguise 219
# Currently processing city %s with index %s nantucket 220
# Key error occurred for city %s. Skipping... ye
# 'clouds'
# Currently processing city %s with index %s tommot 222
# Currently processing city %s with index %s preobrazheniye 223
# Key error occurred for city %s. Skipping... samusu
# 'clouds'
# Currently processing city %s with index %s nhamunda 225
# Currently processing city %s with index %s clarence town 226
# Currently processing city %s with index %s luderitz 227
# Currently processing city %s with index %s ahvaz 228
# Key error occurred for city %s. Skipping... belle fourche
# 'clouds'
# Currently processing city %s with index %s salalah 230
# Currently processing city %s with index %s jambi 231
# Currently processing city %s with index %s tiksi 232
# Currently processing city %s with index %s yakeshi 233
# Currently processing city %s with index %s shumikha 234
# Currently processing city %s with index %s constantine 235
# Currently processing city %s with index %s mackenzie 236
# Currently processing city %s with index %s half moon bay 237
# Currently processing city %s with index %s jacareacanga 238
# Currently processing city %s with index %s svetlogorsk 239
# Currently processing city %s with index %s taoudenni 240
# Currently processing city %s with index %s dwarahat 241
# Currently processing city %s with index %s mezen 242
# Currently processing city %s with index %s ocampo 243
# Currently processing city %s with index %s waipawa 244
# Key error occurred for city %s. Skipping... la ronge
# 'clouds'
# Currently processing city %s with index %s rock sound 246
# Currently processing city %s with index %s liberty 247
# Key error occurred for city %s. Skipping... olafsvik
# 'clouds'
# Currently processing city %s with index %s andra 249
# Currently processing city %s with index %s irmo 250
# Currently processing city %s with index %s padang 251
# Currently processing city %s with index %s bethel 252
# Currently processing city %s with index %s mount pleasant 253
# Currently processing city %s with index %s callaguip 254
# Currently processing city %s with index %s hithadhoo 255
# Currently processing city %s with index %s ayolas 256
# Currently processing city %s with index %s portland 257
# Currently processing city %s with index %s marsh harbour 258
# Currently processing city %s with index %s samarai 259
# Currently processing city %s with index %s makakilo city 260
# Currently processing city %s with index %s mayumba 261
# Currently processing city %s with index %s kasongo-lunda 262
# Currently processing city %s with index %s kavieng 263
# Currently processing city %s with index %s linqiong 264
# Currently processing city %s with index %s upata 265
# Currently processing city %s with index %s tarata 266
# Currently processing city %s with index %s lidkoping 267
# Currently processing city %s with index %s lufilufi 268
# Currently processing city %s with index %s port blair 269
# Currently processing city %s with index %s yar-sale 270
# Key error occurred for city %s. Skipping... bolungarvik
# 'clouds'
# Currently processing city %s with index %s souillac 272
# Currently processing city %s with index %s cidreira 273
# Currently processing city %s with index %s havelock 274
# Currently processing city %s with index %s barcelos 275
# Currently processing city %s with index %s okha 276
# Key error occurred for city %s. Skipping... nizhneyansk
# 'clouds'
# Currently processing city %s with index %s riyadh 278
# Currently processing city %s with index %s sabang 279
# Currently processing city %s with index %s ngaoundere 280
# Currently processing city %s with index %s worland 281
# Currently processing city %s with index %s honolulu 282
# Currently processing city %s with index %s port hardy 283
# Key error occurred for city %s. Skipping... gurupa
# 'clouds'
# Currently processing city %s with index %s gigmoto 285
# Currently processing city %s with index %s lima 286
# Currently processing city %s with index %s noumea 287
# Currently processing city %s with index %s miraflores 288
# Currently processing city %s with index %s berlevag 289
# Currently processing city %s with index %s victoria 290
# Currently processing city %s with index %s praia da vitoria 291
# Currently processing city %s with index %s provideniya 292
# Currently processing city %s with index %s ayorou 293
# Currently processing city %s with index %s mount gambier 294
# Currently processing city %s with index %s saint-paul 295
# Key error occurred for city %s. Skipping... meyungs
# 'clouds'
# Key error occurred for city %s. Skipping... andrelandia
# 'clouds'
# Currently processing city %s with index %s sitka 298
# Key error occurred for city %s. Skipping... karaul
# 'clouds'
# Currently processing city %s with index %s mocorito 300
# Currently processing city %s with index %s tawang 301
# Currently processing city %s with index %s naze 302
# Currently processing city %s with index %s santa lucia 303
# Currently processing city %s with index %s khovu-aksy 304
# Currently processing city %s with index %s oparino 305
# Key error occurred for city %s. Skipping... ust-kamchatsk
# 'clouds'
# Currently processing city %s with index %s kruisfontein 307
# Key error occurred for city %s. Skipping... miranorte
# 'clouds'
# Currently processing city %s with index %s machico 309
# Currently processing city %s with index %s anadyr 310
# Currently processing city %s with index %s severo-yeniseyskiy 311
# Currently processing city %s with index %s powell river 312
# Currently processing city %s with index %s petropavlovsk-kamchatskiy 313
# Currently processing city %s with index %s ponta do sol 314
# Currently processing city %s with index %s kaupanger 315
# Currently processing city %s with index %s dingle 316
# Currently processing city %s with index %s codrington 317
# Currently processing city %s with index %s shetpe 318
# Currently processing city %s with index %s qaanaaq 319
# Currently processing city %s with index %s emerald 320
# Key error occurred for city %s. Skipping... chaa-khol
# 'clouds'
# Currently processing city %s with index %s muroto 322
# Currently processing city %s with index %s copiapo 323
# Currently processing city %s with index %s katsuura 324
# Currently processing city %s with index %s ibra 325
# Currently processing city %s with index %s edson 326
# Currently processing city %s with index %s venice 327
# Key error occurred for city %s. Skipping... hunza
# 'clouds'
# Currently processing city %s with index %s deloraine 329
# Key error occurred for city %s. Skipping... warqla
# 'clouds'
# Currently processing city %s with index %s bilibino 331
# Currently processing city %s with index %s midland 332
# Currently processing city %s with index %s cam ranh 333
# Currently processing city %s with index %s merville 334
# Currently processing city %s with index %s beringovskiy 335
# Currently processing city %s with index %s tezu 336
# Currently processing city %s with index %s monreal 337
# Key error occurred for city %s. Skipping... bargal
# 'clouds'
# Currently processing city %s with index %s pangkalanbuun 339
# Currently processing city %s with index %s nouadhibou 340
# Currently processing city %s with index %s sulphur 341
# Currently processing city %s with index %s verkhniy fiagdon 342
# Currently processing city %s with index %s vandoeuvre-les-nancy 343
# Currently processing city %s with index %s tala 344
# Currently processing city %s with index %s minot 345
# Currently processing city %s with index %s cockburn town 346
# Currently processing city %s with index %s nishihara 347
# Currently processing city %s with index %s ligayan 348
# Key error occurred for city %s. Skipping... thai binh
# 'clouds'
# Currently processing city %s with index %s novouzensk 350
# Currently processing city %s with index %s goya 351
# Currently processing city %s with index %s vila velha 352
# Key error occurred for city %s. Skipping... cravo norte
# 'clouds'
# Currently processing city %s with index %s vostok 354
# Currently processing city %s with index %s grand gaube 355
# Currently processing city %s with index %s songjianghe 356
# Currently processing city %s with index %s babushkin 357
# Currently processing city %s with index %s dese 358
# Currently processing city %s with index %s hickory 359
# Currently processing city %s with index %s valladolid 360
# Key error occurred for city %s. Skipping... ngukurr
# 'clouds'
# Currently processing city %s with index %s zabaykalsk 362
# Key error occurred for city %s. Skipping... pemangkat
# 'clouds'
# Currently processing city %s with index %s victoria point 364
# Currently processing city %s with index %s junagarh 365
# Key error occurred for city %s. Skipping... labutta
# 'clouds'
# Key error occurred for city %s. Skipping... khonuu
# 'clouds'
# Currently processing city %s with index %s torbay 368
# Currently processing city %s with index %s felipe carrillo puerto 369
# Currently processing city %s with index %s timbiqui 370
# Currently processing city %s with index %s kulti 371
# Currently processing city %s with index %s westport 372
# Currently processing city %s with index %s humaita 373
# Currently processing city %s with index %s northam 374
# Currently processing city %s with index %s greenwood 375
# Currently processing city %s with index %s belmonte 376
# Key error occurred for city %s. Skipping... yurya
# 'clouds'
# Currently processing city %s with index %s gamboma 378
# Currently processing city %s with index %s port elizabeth 379
# Key error occurred for city %s. Skipping... svetlyy
# 'clouds'
# Currently processing city %s with index %s aginskoye 381
# Currently processing city %s with index %s puerto lempira 382
# Currently processing city %s with index %s marawi 383
# Currently processing city %s with index %s niono 384
# Key error occurred for city %s. Skipping... doume
# 'clouds'
# Currently processing city %s with index %s vancouver 386
# Currently processing city %s with index %s plettenberg bay 387
# Key error occurred for city %s. Skipping... tabialan
# 'clouds'
# Currently processing city %s with index %s poum 389
# Currently processing city %s with index %s flin flon 390
# Currently processing city %s with index %s seoul 391
# Currently processing city %s with index %s tokmak 392
# Currently processing city %s with index %s evanston 393
# Currently processing city %s with index %s pontes e lacerda 394
# Currently processing city %s with index %s turukhansk 395
# Currently processing city %s with index %s kargil 396
# Currently processing city %s with index %s alofi 397
# Currently processing city %s with index %s antofagasta 398
# Currently processing city %s with index %s iskateley 399
# Key error occurred for city %s. Skipping... rudbar
# 'clouds'
# Currently processing city %s with index %s dwarka 401
# Key error occurred for city %s. Skipping... ciudad bolivar
# 'clouds'
# Currently processing city %s with index %s puerto penasco 403
# Currently processing city %s with index %s chingirlau 404
# Currently processing city %s with index %s qinhuangdao 405
# Currently processing city %s with index %s mys shmidta 406
# Currently processing city %s with index %s mackay 407
# Key error occurred for city %s. Skipping... juifang
# 'clouds'
# Currently processing city %s with index %s nyurba 409
# Currently processing city %s with index %s namibe 410
# Currently processing city %s with index %s paragominas 411
# Currently processing city %s with index %s sibolga 412
# Currently processing city %s with index %s mantua 413
# Currently processing city %s with index %s mangrol 414
# Currently processing city %s with index %s garmsar 415
# Currently processing city %s with index %s jidong 416
# Currently processing city %s with index %s caibarien 417
# Currently processing city %s with index %s alekseyevka 418
# Key error occurred for city %s. Skipping... inderborskiy
# 'clouds'
# Currently processing city %s with index %s budhlada 420
# Currently processing city %s with index %s sao joao da barra 421
# Currently processing city %s with index %s uhlove 422
# Currently processing city %s with index %s puri 423
# Currently processing city %s with index %s orebro 424
# Currently processing city %s with index %s iqaluit 425
# Currently processing city %s with index %s lamu 426
# Key error occurred for city %s. Skipping... tsihombe
# 'clouds'
# Currently processing city %s with index %s oia 428
# Currently processing city %s with index %s dicabisagan 429
# Key error occurred for city %s. Skipping... nasrullaganj
# 'clouds'
# Currently processing city %s with index %s novobirilyussy 431
# Currently processing city %s with index %s caravelas 432
# Currently processing city %s with index %s ostrovnoy 433
# Currently processing city %s with index %s damietta 434
# Currently processing city %s with index %s strezhevoy 435
# Currently processing city %s with index %s ulladulla 436
# Key error occurred for city %s. Skipping... ha tinh
# 'clouds'
# Currently processing city %s with index %s kieta 438
# Currently processing city %s with index %s valparaiso 439
# Currently processing city %s with index %s nzerekore 440
# Currently processing city %s with index %s kahului 441
# Currently processing city %s with index %s harper 442
# Currently processing city %s with index %s baykit 443
# Currently processing city %s with index %s leningradskiy 444
# Key error occurred for city %s. Skipping... rungata
# 'clouds'
# Currently processing city %s with index %s bambanglipuro 446
# Currently processing city %s with index %s avera 447
# Currently processing city %s with index %s kavaratti 448
# Currently processing city %s with index %s saint-georges 449
# Currently processing city %s with index %s saint-pierre 450
# Currently processing city %s with index %s mbandaka 451
# Currently processing city %s with index %s vangaindrano 452
# Key error occurred for city %s. Skipping... chagda
# 'clouds'
# Currently processing city %s with index %s maracacume 454
# Currently processing city %s with index %s matara 455
# Currently processing city %s with index %s sann 456
# Currently processing city %s with index %s impfondo 457
# Currently processing city %s with index %s dong hoi 458
# Currently processing city %s with index %s sinnamary 459
# Currently processing city %s with index %s karratha 460
# Key error occurred for city %s. Skipping... halalo
# 'clouds'
# Currently processing city %s with index %s oistins 462
# Currently processing city %s with index %s college 463
# Currently processing city %s with index %s atikokan 464
# Currently processing city %s with index %s sagar 465
# Currently processing city %s with index %s dawei 466
# Currently processing city %s with index %s derzhavinsk 467
# Currently processing city %s with index %s kampot 468
# Currently processing city %s with index %s acapulco 469
# Currently processing city %s with index %s mareeba 470
# Currently processing city %s with index %s fortuna 471
# Currently processing city %s with index %s milos 472
# Currently processing city %s with index %s luwuk 473
# Currently processing city %s with index %s tazmalt 474
# Currently processing city %s with index %s pisco 475
# Currently processing city %s with index %s vila 476
# Currently processing city %s with index %s lompoc 477
# Currently processing city %s with index %s rio cuarto 478
# Currently processing city %s with index %s kanepi 479
# Currently processing city %s with index %s torres 480
# Currently processing city %s with index %s shache 481
# Currently processing city %s with index %s kuching 482
# Currently processing city %s with index %s boddam 483
# Currently processing city %s with index %s yenagoa 484
# Key error occurred for city %s. Skipping... simplicio mendes
# 'clouds'
# Currently processing city %s with index %s xenia 486
# Currently processing city %s with index %s manta 487
# Currently processing city %s with index %s talnakh 488
# Currently processing city %s with index %s yerbogachen 489
# Currently processing city %s with index %s sao filipe 490
# Currently processing city %s with index %s khandyga 491
# Currently processing city %s with index %s sitangkai 492
# Key error occurred for city %s. Skipping... diego de almagro
# 'clouds'
# Currently processing city %s with index %s aswan 494
# Currently processing city %s with index %s aykhal 495
# Key error occurred for city %s. Skipping... nakhon si thammarat
# 'clouds'
# Currently processing city %s with index %s mandalgovi 497
# Currently processing city %s with index %s moroni 498
# Currently processing city %s with index %s necochea 499
# Currently processing city %s with index %s san blas 500
# Currently processing city %s with index %s rostock 501
# Currently processing city %s with index %s altoona 502
# Currently processing city %s with index %s coihaique 503
# Currently processing city %s with index %s emmett 504
# Currently processing city %s with index %s redlands 505
# Currently processing city %s with index %s kharp 506
# Currently processing city %s with index %s itarema 507
# Currently processing city %s with index %s christchurch 508
# Currently processing city %s with index %s nizhniy kuranakh 509
# Currently processing city %s with index %s carutapera 510
# Currently processing city %s with index %s xining 511
# Key error occurred for city %s. Skipping... paradwip
# 'clouds'
# Currently processing city %s with index %s saint-francois 513
# Currently processing city %s with index %s mbuguni 514
# Currently processing city %s with index %s carndonagh 515
# Currently processing city %s with index %s dongsheng 516
# Currently processing city %s with index %s tura 517
# Currently processing city %s with index %s ndola 518
# Currently processing city %s with index %s prabumulih 519
# Currently processing city %s with index %s tulsipur 520
# Key error occurred for city %s. Skipping... amderma
# 'clouds'
# Key error occurred for city %s. Skipping... satitoa
# 'clouds'
# Currently processing city %s with index %s bermejo 523
# Currently processing city %s with index %s wanlaweyn 524
# Currently processing city %s with index %s dutlwe 525
# Key error occurred for city %s. Skipping... higuey
# 'clouds'
# Currently processing city %s with index %s xingyi 527
# Currently processing city %s with index %s dahra 528
# Currently processing city %s with index %s shubarkuduk 529
# Currently processing city %s with index %s virginia beach 530
# Key error occurred for city %s. Skipping... jibuti
# 'clouds'
# Currently processing city %s with index %s qui nhon 532
# Currently processing city %s with index %s tabas 533
# Currently processing city %s with index %s jiangyou 534
# Currently processing city %s with index %s visnes 535
# Currently processing city %s with index %s yelizovo 536
# Key error occurred for city %s. Skipping... toftir
# 'clouds'
# Currently processing city %s with index %s unnao 538
# Currently processing city %s with index %s yaan 539
# Currently processing city %s with index %s unity 540
# Currently processing city %s with index %s alpena 541
# Currently processing city %s with index %s berdigestyakh 542
# Currently processing city %s with index %s kuala lipis 543
# Currently processing city %s with index %s ondjiva 544
# Currently processing city %s with index %s boa vista 545
# Key error occurred for city %s. Skipping... krasnoselkup
# 'clouds'
# Key error occurred for city %s. Skipping... saint george
# 'clouds'
# Currently processing city %s with index %s valente 548
# Currently processing city %s with index %s lagos 549
# Currently processing city %s with index %s kyle of lochalsh 550
# Currently processing city %s with index %s lozovo 551
# Currently processing city %s with index %s cabedelo 552
# Currently processing city %s with index %s kudahuvadhoo 553
# Currently processing city %s with index %s lata 554
# Currently processing city %s with index %s springbok 555
# Currently processing city %s with index %s hsinchu 556
# Currently processing city %s with index %s saiha 557
# Currently processing city %s with index %s gat 558
# Currently processing city %s with index %s ouegoa 559
# Currently processing city %s with index %s hauge 560
# Currently processing city %s with index %s puerto colombia 561
# Currently processing city %s with index %s tilichiki 562
# Currently processing city %s with index %s gagnoa 563
# Currently processing city %s with index %s passo de camaragibe 564
# Key error occurred for city %s. Skipping... sakakah
# 'clouds'
# Currently processing city %s with index %s san juan 566
# Currently processing city %s with index %s payson 567
# Currently processing city %s with index %s kyzyl-suu 568
# Currently processing city %s with index %s kibara 569
# Key error occurred for city %s. Skipping... manoel urbano
# 'clouds'
# Currently processing city %s with index %s port hedland 571
# Currently processing city %s with index %s puteyets 572
# Currently processing city %s with index %s kloulklubed 573
# Currently processing city %s with index %s san patricio 574
# Currently processing city %s with index %s lamballe 575
# Currently processing city %s with index %s hovd 576
# Currently processing city %s with index %s aksakovo 577
# Currently processing city %s with index %s pahrump 578
# Currently processing city %s with index %s geraldton 579
# Currently processing city %s with index %s krynychky 580
# Currently processing city %s with index %s jadu 581
# Key error occurred for city %s. Skipping... babanusah
# 'clouds'
# Currently processing city %s with index %s houma 583
# Currently processing city %s with index %s shemonaikha 584
# Currently processing city %s with index %s tshikapa 585
# Currently processing city %s with index %s zhanaozen 586
# Key error occurred for city %s. Skipping... bababe
# 'clouds'
# Currently processing city %s with index %s sobreira 588
# Currently processing city %s with index %s comodoro rivadavia 589
# Currently processing city %s with index %s buala 590
# Currently processing city %s with index %s laurel 591
# Currently processing city %s with index %s mahibadhoo 592
# Currently processing city %s with index %s tulu bolo 593
# Currently processing city %s with index %s port keats 594
# Currently processing city %s with index %s ferme-neuve 595
# Currently processing city %s with index %s port lincoln 596
# Currently processing city %s with index %s olmos 597
# Currently processing city %s with index %s olden 598
# Currently processing city %s with index %s merrill 599
# Currently processing city %s with index %s san ramon 600
# Key error occurred for city %s. Skipping... kushmurun
# 'clouds'
# Currently processing city %s with index %s caranan 602
# Currently processing city %s with index %s ritchie 603
# Currently processing city %s with index %s vanimo 604
# Key error occurred for city %s. Skipping... kyra
# 'clouds'
# Currently processing city %s with index %s wanning 606
# Key error occurred for city %s. Skipping... jabiru
# 'clouds'
# Currently processing city %s with index %s sao felix do xingu 608
# Currently processing city %s with index %s sampang 609
# Currently processing city %s with index %s vila do maio 610
# Currently processing city %s with index %s pedernales 611
# Key error occurred for city %s. Skipping... umm lajj
# 'clouds'
# Key error occurred for city %s. Skipping... korla
# 'clouds'
# Currently processing city %s with index %s mayskiy 614
# Currently processing city %s with index %s mocuba 615
# Currently processing city %s with index %s owo 616
# Currently processing city %s with index %s stranraer 617
# Currently processing city %s with index %s gazojak 618
# Currently processing city %s with index %s isangel 619

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Space junk
#type(weatherbycity_df)
#for col in weatherbycity_df: 
    #print(col) 
#weatherbycity_df.columns
#weatherbycity_df.set_index(city)
#pd.weatherbycity_df.transpose
#weatherbycity_df(t(df))
#weatherbycity_df[nrow(weatherbycity_df):1, ]

# %%
weatherbycity_df = pd.DataFrame(weather_information_by_city)
weatherbycity_df = weatherbycity_df.T
weatherbycity_df.index.name = 'City'

weatherbycity_df.head()
# Out:
#                        cloudiness country          dt humidity    lat     lon  \
# City
# grand river south east         96      FR  1569968913       87  48.39    5.49
# kovur                          46      IN  1569968913       78   14.5   79.99
# bredasdorp                    100      ZA  1569968913       82 -34.53   20.04
# saldanha                        0      PT  1569968913       60  41.42   -6.55
# bluff                           2      AU  1569968914       77 -23.58  149.07
#
#                        max_temperature wind_speed
# City
# grand river south east              59      14.99
# kovur                            80.16       2.24
# bredasdorp                       60.01       3.36
# saldanha                          58.7      11.97
# bluff                            64.98      14.47

# %%
#output data to csv
weatherbycity_df.to_csv("weatherbycity.csv", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weatherbycity_df["lat"],weatherbycity_df["max_temperature"], c="lightblue", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Max Temp Aug 30 2019")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey") 
plt.savefig("fig1.jpg")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weatherbycity_df["lat"],weatherbycity_df["humidity"], c="lightblue", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs Humidity Aug 30 2019")
plt.xlabel("Latitude")
plt.ylabel("Humidity%")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey") 
plt.savefig("fig2.jpg")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherbycity_df["lat"],weatherbycity_df["cloudiness"], c="lightblue", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs Cloudiness Aug 30 2019")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness%")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey") 
plt.savefig("fig3.jpg")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherbycity_df["lat"],weatherbycity_df["wind_speed"], c="lightblue", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs Wind_speed Aug 30 2019")
plt.xlabel("Latitude")
plt.ylabel("Wind_speed MPH")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey") 
plt.savefig("fig4.jpg")
plt.show()
